# %% [markdown]
# # final project using ML to predict accident severity
# # range is from 1-4 with 1 being the least impact on traffic and 4 indicating significant impact on traffic

# %% [markdown]
# # i am tried to choose TX and Harris county(metro Houston area) but ran into issues seperating
# # out the state so i ran my analysis on the entire dataset

# %% [markdown]
# # import packages

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# * load in data

# %%
accidents = pd.read_csv('C:/Users/trece/OneDrive/Desktop/US_Accidents_May19.csv')

# %% [markdown]
# ## show all the columns

# %%
pd.set_option("display.max.columns", None)

# %%
accidents.head(40)
# Out:
#       ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0    A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1    A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2    A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3    A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4    A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5    A-6  MapQuest  201.0         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6    A-7  MapQuest  201.0         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7    A-8  MapQuest  201.0         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8    A-9  MapQuest  201.0         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9   A-10  MapQuest  201.0         3  2016-02-08 08:10:04  2016-02-08 08:40:04
# 10  A-11  MapQuest  201.0         3  2016-02-08 08:14:42  2016-02-08 08:44:42
# ...

# %%
accidents1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243939 entries, 0 to 2243938
# Data columns (total 26 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               object
#  1   Source           object
#  2   Severity         int64
#  3   Start_Time       object
#  4   End_Time         object
#  5   Start_Lat        float64
#  6   Start_Lng        float64
#  7   Distance(mi)     float64
#  8   Street           object
#  9   Side             object
#  10  County           object
#  11  State            object
#  12  Country          object
#  13  Amenity          bool
#  14  Bump             bool
#  15  Crossing         bool
#  16  Give_Way         bool
#  17  Junction         bool
#  18  No_Exit          bool
#  19  Railway          bool
#  20  Roundabout       bool
#  21  Station          bool
#  22  Stop             bool
#  23  Traffic_Calming  bool
#  24  Traffic_Signal   bool
#  25  Turning_Loop     bool
# ...

# %%
accidents['Zipcode']= accidents['Zipcode'].str[:5]

# %%
accidents.head(40)
# Out:
#       ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0    A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1    A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2    A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3    A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4    A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5    A-6  MapQuest  201.0         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6    A-7  MapQuest  201.0         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7    A-8  MapQuest  201.0         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8    A-9  MapQuest  201.0         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9   A-10  MapQuest  201.0         3  2016-02-08 08:10:04  2016-02-08 08:40:04
# 10  A-11  MapQuest  201.0         3  2016-02-08 08:14:42  2016-02-08 08:44:42
# ...

# %%
state = 'TX'

# %%
accidents_TX=def_sel.loc[def_sel.State==TX].copy()
accidents_TX.drop('State',axis=1, inplace=True)
accidents_TX.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/2198887913.py in <module>
# ----> 1 accidents_TX=def_sel.loc[def_sel.State==TX].copy()
#       2 accidents_TX.drop('State',axis=1, inplace=True)
#       3 accidents_TX.info()
#
# NameError: name 'def_sel' is not defined

# %% [markdown]
# ## define x and y variables

# %%
x= accidents[['Distance(mi)', 'County',  'Zipcode', 'Sunrise_Sunset', 'Traffic_Signal', 'Start_Lat', 'Start_Lng', 'Temperature(F)']]

# %%
y = accidents['Severity']

# %% [markdown]
# # define train and test model

# %%
x_train, y_train, x_test, y_test = train_test_split(x,y, test_size = 0.4,)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1346363, 8) (897576, 8)
# (1346363,) (897576,)

# %% [markdown]
# # make a linear regression model and run it on the training data

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11748/141332336.py in <module>
# ----> 1 lm.fit(x_train, y_train)
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# C:\Python3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
