# %% [markdown]
# # Final Project in Python - Distracted Driving

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
plt.style.use('ggplot')
from matplotlib import*
from pylab import*
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox

# %% [markdown]
# # Import Data

# %%
accident=pd.read_csv("accident.csv")

# %%
accident.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0      1    10001         1         1         0     0           0        1
# 1      1    10002         1         1         0     0           0        1
# 2      1    10003         1         1         0     0           0        2
# 3      1    10004         1         1         0     0           0        1
# 4      1    10005         2         2         0     0           0        2
#
#    PERSONS  COUNTY  CITY  DAY  MONTH  YEAR  DAY_WEEK  HOUR  MINUTE  NHS  \
# 0        1     127     0    1      1  2015         5     2      40    0
# 1        1      83     0    1      1  2015         5    22      13    1
# 2        2      11     0    1      1  2015         5     1      25    0
# 3        1      45     0    4      1  2015         1     0      57    0
# 4        2      45  2050    7      1  2015         4     7       9    0
#
#    RUR_URB  FUNC_SYS  RD_OWNER  ROUTE   TWAY_ID           TWAY_ID2  MILEPT  \
# 0        1         3         1      3      SR-5                NaN    1754
# 1        1         1         1      1      I-65                NaN    3604
# 2        1         3         1      2   US-SR 6                NaN    1958
# 3        1         4         1      3     SR-27                NaN     566
# 4        2         3         1      2  US-SR 53  HINTON WATERS AVE     308
#
#     LATITUDE   LONGITUD  SP_JUR  HARM_EV  MAN_COLL  RELJCT1  RELJCT2  TYP_INT  \
# 0  33.878653 -87.325328       0       35         0        0        1        1
# 1  34.910442 -86.908708       0       34         0        0        1        1
# 2  32.142006 -85.758456       0       42         0        0        1        1
# 3  31.439814 -85.510300       0       53         0        0        1        1
# 4  31.319331 -85.515100       0       12         6        0        2        3
#
#    WRK_ZONE  REL_ROAD  LGT_COND  WEATHER1  WEATHER2  WEATHER  SCH_BUS  \
# 0         0         4         2         1         0        1        0
# 1         0         3         2        10         0       10        0
# 2         0         4         2         1         0        1        0
# 3         0         4         2        10         0       10        0
# 4         0         1         1         1         0        1        0
#
#       RAIL  NOT_HOUR  NOT_MIN  ARR_HOUR  ARR_MIN  HOSP_HR  HOSP_MN  CF1  CF2  \
# 0  0000000        99       99         2       58       88       88    0    0
# 1  0000000        99       99        22       20       88       88    0    0
# 2  0000000        99       99         1       45       99       99    0    0
# 3  0000000        99       99         1       15       88       88    0    0
# 4  0000000        99       99         7       16       88       88    0    0
#
#    CF3  FATALS  DRUNK_DR
# 0    0       1         1
# 1    0       1         0
# 2    0       1         1
# 3    0       1         1
# 4    0       1         0

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32166 entries, 0 to 32165
# Data columns (total 52 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE       32166 non-null  int64
#  1   ST_CASE     32166 non-null  int64
#  2   VE_TOTAL    32166 non-null  int64
#  3   VE_FORMS    32166 non-null  int64
#  4   PVH_INVL    32166 non-null  int64
#  5   PEDS        32166 non-null  int64
#  6   PERNOTMVIT  32166 non-null  int64
#  7   PERMVIT     32166 non-null  int64
#  8   PERSONS     32166 non-null  int64
#  9   COUNTY      32166 non-null  int64
#  10  CITY        32166 non-null  int64
#  11  DAY         32166 non-null  int64
#  12  MONTH       32166 non-null  int64
#  13  YEAR        32166 non-null  int64
#  14  DAY_WEEK    32166 non-null  int64
#  15  HOUR        32166 non-null  int64
#  16  MINUTE      32166 non-null  int64
#  17  NHS         32166 non-null  int64
#  18  RUR_URB     32166 non-null  int64
#  19  FUNC_SYS    32166 non-null  int64
#  20  RD_OWNER    32166 non-null  int64
#  21  ROUTE       32166 non-null  int64
#  22  TWAY_ID     32166 non-null  object
#  23  TWAY_ID2    8400 non-null   object
#  24  MILEPT      32166 non-null  int64
#  25  LATITUDE    32166 non-null  float64
#  26  LONGITUD    32166 non-null  float64
#  27  SP_JUR      32166 non-null  int64
#  28  HARM_EV     32166 non-null  int64
#  29  MAN_COLL    32166 non-null  int64
#  30  RELJCT1     32166 non-null  int64
#  31  RELJCT2     32166 non-null  int64
#  32  TYP_INT     32166 non-null  int64
#  33  WRK_ZONE    32166 non-null  int64
#  34  REL_ROAD    32166 non-null  int64
#  35  LGT_COND    32166 non-null  int64
#  36  WEATHER1    32166 non-null  int64
#  37  WEATHER2    32166 non-null  int64
#  38  WEATHER     32166 non-null  int64
#  39  SCH_BUS     32166 non-null  int64
#  40  RAIL        32166 non-null  object
#  41  NOT_HOUR    32166 non-null  int64
#  42  NOT_MIN     32166 non-null  int64
#  43  ARR_HOUR    32166 non-null  int64
#  44  ARR_MIN     32166 non-null  int64
#  45  HOSP_HR     32166 non-null  int64
#  46  HOSP_MN     32166 non-null  int64
#  47  CF1         32166 non-null  int64
#  48  CF2         32166 non-null  int64
#  49  CF3         32166 non-null  int64
#  50  FATALS      32166 non-null  int64
#  51  DRUNK_DR    32166 non-null  int64
# dtypes: float64(2), int64(47), object(3)
# memory usage: 12.8+ MB

# %%
distract=pd.read_csv("distract.csv")

# %%
distract.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MDRDSTRD
# 0      1    10001       1        99
# 1      1    10002       1         0
# 2      1    10003       1         0
# 3      1    10004       1        99
# 4      1    10005       1        99

# %%
distract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48962 entries, 0 to 48961
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATE     48962 non-null  int64
#  1   ST_CASE   48962 non-null  int64
#  2   VEH_NO    48962 non-null  int64
#  3   MDRDSTRD  48962 non-null  int64
# dtypes: int64(4)
# memory usage: 1.5 MB

# %%
distract1=pd.merge(accident,distract)

# %%
distract1
# Out:
#        STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  \
# 0          1    10001         1         1         0     0           0
# 1          1    10002         1         1         0     0           0
# 2          1    10003         1         1         0     0           0
# 3          1    10004         1         1         0     0           0
# 4          1    10005         2         2         0     0           0
# ...      ...      ...       ...       ...       ...   ...         ...
# 48957     56   560128         2         2         0     0           0
# 48958     56   560128         2         2         0     0           0
# 48959     56   560129         2         2         0     0           0
# 48960     56   560129         2         2         0     0           0
# 48961     56   560130         1         1         0     0           0
#
#        PERMVIT  PERSONS  COUNTY  CITY  DAY  MONTH  YEAR  DAY_WEEK  HOUR  \
# 0            1        1     127     0    1      1  2015         5     2
# 1            1        1      83     0    1      1  2015         5    22
# 2            2        2      11     0    1      1  2015         5     1
# 3            1        1      45     0    4      1  2015         1     0
# 4            2        2      45  2050    7      1  2015         4     7
# ...        ...      ...     ...   ...  ...    ...   ...       ...   ...
# 48957        2        2      21   100   13     12  2015         1    11
# 48958        2        2      21   100   13     12  2015         1    11
# 48959        4        4      21     0   14     12  2015         2    23
# 48960        4        4      21     0   14     12  2015         2    23
# 48961        1        1      33     0   19     12  2015         7    21
#
#        MINUTE  NHS  RUR_URB  FUNC_SYS  RD_OWNER  ROUTE   TWAY_ID  \
# 0          40    0        1         3         1      3      SR-5
# 1          13    1        1         1         1      1      I-65
# 2          25    0        1         3         1      2   US-SR 6
# 3          57    0        1         4         1      3     SR-27
# 4           9    0        2         3         1      2  US-SR 53
# ...       ...  ...      ...       ...       ...    ...       ...
# 48957      50    1        2         3         1      2     US-30
# 48958      50    1        2         3         1      2     US-30
# 48959       5    0        1         3         1      2     US-85
# 48960       5    0        1         3         1      2     US-85
# 48961      55    1        1         3         1      2     US-14
#
#                 TWAY_ID2  MILEPT   LATITUDE    LONGITUD  SP_JUR  HARM_EV  \
# 0                    NaN    1754  33.878653  -87.325328       0       35
# 1                    NaN    3604  34.910442  -86.908708       0       34
# 2                    NaN    1958  32.142006  -85.758456       0       42
# 3                    NaN     566  31.439814  -85.510300       0       53
# 4      HINTON WATERS AVE     308  31.319331  -85.515100       0       12
# ...                  ...     ...        ...         ...     ...      ...
# 48957           REESE RD    3691  41.159400 -104.694200       0       12
# 48958           REESE RD    3691  41.159400 -104.694200       0       12
# 48959                NaN     533  41.531100 -104.328600       0       12
# 48960                NaN     533  41.531100 -104.328600       0       12
# 48961                NaN     760  44.823689 -107.328131       0        1
#
#        MAN_COLL  RELJCT1  RELJCT2  TYP_INT  WRK_ZONE  REL_ROAD  LGT_COND  \
# 0             0        0        1        1         0         4         2
# 1             0        0        1        1         0         3         2
# 2             0        0        1        1         0         4         2
# 3             0        0        1        1         0         4         2
# 4             6        0        2        3         0         1         1
# ...         ...      ...      ...      ...       ...       ...       ...
# 48957         6        0        2        2         0         1         1
# 48958         6        0        2        2         0         1         1
# 48959         6        0        1        1         0         1         2
# 48960         6        0        1        1         0         1         2
# 48961         0        0        1        1         0         1         2
#
#        WEATHER1  WEATHER2  WEATHER  SCH_BUS     RAIL  NOT_HOUR  NOT_MIN  \
# 0             1         0        1        0  0000000        99       99
# 1            10         0       10        0  0000000        99       99
# 2             1         0        1        0  0000000        99       99
# 3            10         0       10        0  0000000        99       99
# 4             1         0        1        0  0000000        99       99
# ...         ...       ...      ...      ...      ...       ...      ...
# 48957         1         0        1        0  0000000        11       54
# 48958         1         0        1        0  0000000        11       54
# 48959         4         0        4        0  0000000        23       12
# 48960         4         0        4        0  0000000        23       12
# 48961         1         0        1        0  0000000        21       59
#
#        ARR_HOUR  ARR_MIN  HOSP_HR  HOSP_MN  CF1  CF2  CF3  FATALS  DRUNK_DR  \
# 0             2       58       88       88    0    0    0       1         1
# 1            22       20       88       88    0    0    0       1         0
# 2             1       45       99       99    0    0    0       1         1
# 3             1       15       88       88    0    0    0       1         1
# 4             7       16       88       88    0    0    0       1         0
# ...         ...      ...      ...      ...  ...  ...  ...     ...       ...
# 48957        12        2       12       32    0    0    0       1         0
# 48958        12        2       12       32    0    0    0       1         0
# 48959        23       55        0       18    0    0    0       1         0
# 48960        23       55        0       18    0    0    0       1         0
# 48961        22       25        1       16    0    0    0       1         0
#
#        VEH_NO  MDRDSTRD
# 0           1        99
# 1           1         0
# 2           1         0
# 3           1        99
# 4           1        99
# ...       ...       ...
# 48957       1         0
# 48958       2        15
# 48959       1        99
# 48960       2         0
# 48961       1         0
#
# [48962 rows x 54 columns]

# %%
distract1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48962 entries, 0 to 48961
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE       48962 non-null  int64
#  1   ST_CASE     48962 non-null  int64
#  2   VE_TOTAL    48962 non-null  int64
#  3   VE_FORMS    48962 non-null  int64
#  4   PVH_INVL    48962 non-null  int64
#  5   PEDS        48962 non-null  int64
#  6   PERNOTMVIT  48962 non-null  int64
#  7   PERMVIT     48962 non-null  int64
#  8   PERSONS     48962 non-null  int64
#  9   COUNTY      48962 non-null  int64
#  10  CITY        48962 non-null  int64
#  11  DAY         48962 non-null  int64
#  12  MONTH       48962 non-null  int64
#  13  YEAR        48962 non-null  int64
#  14  DAY_WEEK    48962 non-null  int64
#  15  HOUR        48962 non-null  int64
#  16  MINUTE      48962 non-null  int64
#  17  NHS         48962 non-null  int64
#  18  RUR_URB     48962 non-null  int64
#  19  FUNC_SYS    48962 non-null  int64
#  20  RD_OWNER    48962 non-null  int64
#  21  ROUTE       48962 non-null  int64
#  22  TWAY_ID     48962 non-null  object
#  23  TWAY_ID2    14733 non-null  object
#  24  MILEPT      48962 non-null  int64
#  25  LATITUDE    48962 non-null  float64
#  26  LONGITUD    48962 non-null  float64
#  27  SP_JUR      48962 non-null  int64
#  28  HARM_EV     48962 non-null  int64
#  29  MAN_COLL    48962 non-null  int64
#  30  RELJCT1     48962 non-null  int64
#  31  RELJCT2     48962 non-null  int64
#  32  TYP_INT     48962 non-null  int64
#  33  WRK_ZONE    48962 non-null  int64
#  34  REL_ROAD    48962 non-null  int64
#  35  LGT_COND    48962 non-null  int64
#  36  WEATHER1    48962 non-null  int64
#  37  WEATHER2    48962 non-null  int64
#  38  WEATHER     48962 non-null  int64
#  39  SCH_BUS     48962 non-null  int64
#  40  RAIL        48962 non-null  object
#  41  NOT_HOUR    48962 non-null  int64
#  42  NOT_MIN     48962 non-null  int64
#  43  ARR_HOUR    48962 non-null  int64
#  44  ARR_MIN     48962 non-null  int64
#  45  HOSP_HR     48962 non-null  int64
#  46  HOSP_MN     48962 non-null  int64
#  47  CF1         48962 non-null  int64
#  48  CF2         48962 non-null  int64
#  49  CF3         48962 non-null  int64
#  50  FATALS      48962 non-null  int64
#  51  DRUNK_DR    48962 non-null  int64
#  52  VEH_NO      48962 non-null  int64
#  53  MDRDSTRD    48962 non-null  int64
# dtypes: float64(2), int64(49), object(3)
# memory usage: 20.5+ MB

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Dropping columns - not needed information

# %%
distract1.drop(['ST_CASE'],axis=1, inplace=True)
distract1.drop(['WEATHER'],axis=1, inplace=True)
distract1.drop(['WEATHER1'],axis=1, inplace=True)
distract1.drop(['WEATHER2'],axis=1, inplace=True)
distract1.drop(['NOT_HOUR'], axis=1, inplace=True)
distract1.drop(['NOT_MIN'], axis=1, inplace=True)
distract1.drop(['NHS'], axis=1,inplace=True)
distract1.drop(['RUR_URB'],axis=1, inplace=True)
distract1.drop(['ARR_HOUR'],axis=1, inplace=True)
distract1.drop(['ARR_MIN'],axis=1, inplace=True)
distract1.drop(['FUNC_SYS'],axis=1, inplace=True)
distract1.drop(['HOSP_HR'],axis=1, inplace=True)
distract1.drop(['HOSP_MN'],axis=1, inplace=True)
distract1.drop(['VE_TOTAL'],axis=1, inplace=True)
distract1.drop(['VE_FORMS'],axis=1, inplace=True)
distract1.drop(['PVH_INVL'],axis=1, inplace=True)
distract1.drop(['PERNOTMVIT'],axis=1, inplace=True)
distract1.drop(['PERMVIT'],axis=1, inplace=True)
distract1.drop(['COUNTY'],axis=1, inplace=True)
distract1.drop(['CITY'],axis=1, inplace=True)
distract1.drop(['DAY'],axis=1, inplace=True)
distract1.drop(['MONTH'],axis=1, inplace=True)
distract1.drop(['YEAR'],axis=1, inplace=True)
distract1.drop(['DAY_WEEK'],axis=1, inplace=True)
distract1.drop(['HOUR'],axis=1, inplace=True)
distract1.drop(['MINUTE'],axis=1, inplace=True)
distract1.drop(['RD_OWNER'],axis=1, inplace=True)
distract1.drop(['ROUTE'],axis=1, inplace=True)
distract1.drop(['TWAY_ID'],axis=1, inplace=True)
distract1.drop(['TWAY_ID2'],axis=1, inplace=True)
distract1.drop(['MILEPT'],axis=1, inplace=True)
distract1.drop(['SP_JUR'],axis=1, inplace=True)
distract1.drop(['HARM_EV'],axis=1, inplace=True)
distract1.drop(['MAN_COLL'],axis=1, inplace=True)
distract1.drop(['RELJCT1'],axis=1, inplace=True)
distract1.drop(['RELJCT2'],axis=1, inplace=True)
distract1.drop(['TYP_INT'],axis=1, inplace=True)
distract1.drop(['WRK_ZONE'],axis=1, inplace=True)
distract1.drop(['REL_ROAD'],axis=1, inplace=True)
distract1.drop(['LGT_COND'],axis=1, inplace=True)
distract1.drop(['RAIL'],axis=1, inplace=True)

# %%
distract1.head()
# Out:
#    STATE  PEDS  PERSONS   LATITUDE   LONGITUD  SCH_BUS  CF1  CF2  CF3  FATALS  \
# 0      1     0        1  33.878653 -87.325328        0    0    0    0       1
# 1      1     0        1  34.910442 -86.908708        0    0    0    0       1
# 2      1     0        2  32.142006 -85.758456        0    0    0    0       1
# 3      1     0        1  31.439814 -85.510300        0    0    0    0       1
# 4      1     0        2  31.319331 -85.515100        0    0    0    0       1
#
#    DRUNK_DR  VEH_NO  MDRDSTRD
# 0         1       1        99
# 1         0       1         0
# 2         1       1         0
# 3         1       1        99
# 4         0       1        99

# %%
distract1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48962 entries, 0 to 48961
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATE     48962 non-null  int64
#  1   PEDS      48962 non-null  int64
#  2   PERSONS   48962 non-null  int64
#  3   LATITUDE  48962 non-null  float64
#  4   LONGITUD  48962 non-null  float64
#  5   SCH_BUS   48962 non-null  int64
#  6   CF1       48962 non-null  int64
#  7   CF2       48962 non-null  int64
#  8   CF3       48962 non-null  int64
#  9   FATALS    48962 non-null  int64
#  10  DRUNK_DR  48962 non-null  int64
#  11  VEH_NO    48962 non-null  int64
#  12  MDRDSTRD  48962 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 5.2 MB

# %% [markdown]
# Decoding Distractions

# %% [markdown]
# List of distractions broken down by numbers

# %%
distractionData = {0: 'Not Distracted', 1: 'Looked But Did Not See',
           3: 'By Other Occupant(s)', 4: 'By a Moving Object in Vehicle',
           5: 'While Talking or Listening to Cellular Phone',
           6: 'While Manipulating Cellular Phone',
           7: 'While Adjusting Audio or Climate Controls',
           9: 'While Using Other Component/Controls Integral to Vehicle',
           10: 'While Using or Reaching For Device/Object Brought Into Vehicle',
           12: 'Distracted by Outside Person, Object or Event',
           13: 'Eating or Drinking',
           14: 'Smoking Related',
           15: 'Other Cellular Phone Related',
           16: 'No Driver Present/Unknown if Driver Present',
           17: 'Distraction/Inattention',
           18: 'Distraction/Careless',
           19: 'Careless/Inattentive',
           92: 'Distraction (Distracted), Details Unknown',
           93: 'Inattention (Inattentive), Details Unknown',
           96: 'Not Reported',
           97: 'Lost In Thought/Day Dreaming',
           98: 'Other Distraction',
           99: 'Unknown if Distracted'}

distract1['distractionData'] = distract1['MDRDSTRD'].apply(lambda x: distractionData[x])

# %% [markdown]
# List of states broken down by numbers

# %%
states = {1: 'Alabama', 2: 'Alaska', 4: 'Arizona', 5: 'Arkansas', 
          6: 'California', 8: 'Colorado', 9: 'Connecticut', 10: 'Delaware', 
          11: 'District of Columbia', 12: 'Florida', 13: 'Georgia', 15: 'Hawaii', 
          16: 'Idaho', 17: 'Illinois', 18: 'Indiana', 19: 'Iowa', 20: 'Kansas', 
          21: 'Kentucky', 22: 'Louisiana', 23: 'Maine', 24: 'Maryland', 
          25: 'Massachusetts', 26: 'Michigan', 27: 'Minnesota', 
          28: 'Mississippi', 29: 'Missouri', 30: 'Montana', 31: 'Nebraska', 
          32: 'Nevada', 33: 'New Hampshire', 34: 'New Jersey', 35: 'New Mexico', 
          36: 'New York', 37: 'North Carolina', 38: 'North Dakota', 39: 'Ohio', 
          40: 'Oklahoma', 41: 'Oregon', 42: 'Pennsylvania', 43: 'Puerto Rico', 
          44: 'Rhode Island', 45: 'South Carolina', 46: 'South Dakota', 47: 'Tennessee', 
          48: 'Texas', 49: 'Utah', 50: 'Vermont', 51: 'Virginia', 52: 'Virgin Islands', 
          53: 'Washington', 54: 'West Virginia', 55: 'Wisconsin', 56: 'Wyoming'}

distract1['state']=distract1['STATE'].apply(lambda x: states[x])

# %%
distract1['state'].value_counts('MDRDSTRD').to_frame()
# Out:
#                          state
# Texas                 0.099996
# California            0.090213
# Florida               0.085066
# Georgia               0.041828
# North Carolina        0.039847
# Pennsylvania          0.034312
# Ohio                  0.033475
# New York              0.030738
# Michigan              0.029411
# South Carolina        0.028716
# Illinois              0.027879
# Tennessee             0.027777
# Arizona               0.025346
# Missouri              0.025224
# Alabama               0.024162
# Indiana               0.023814
# Kentucky              0.022078
# Virginia              0.020751
# Louisiana             0.020526
# Oklahoma              0.018177
# Mississippi           0.017830
# Wisconsin             0.016482
# Colorado              0.016135
# Washington            0.016115
# New Jersey            0.015543
# Arkansas              0.014971
# Maryland              0.014767
# Oregon                0.012193
# Minnesota             0.012132
# Kansas                0.009558
# Nevada                0.009272
# Iowa                  0.008599
# Utah                  0.008578
# Massachusetts         0.008435
# New Mexico            0.007822
# Connecticut           0.007639
# West Virginia         0.007251
# Nebraska              0.006781
# Idaho                 0.005719
# Montana               0.005494
# Maine                 0.004064
# Wyoming               0.003942
# Delaware              0.003901
# South Dakota          0.003452
# North Dakota          0.003431
# New Hampshire         0.002921
# Hawaii                0.002594
# Alaska                0.001818
# Vermont               0.001430
# Rhode Island          0.001185
# District of Columbia  0.000613

# %% [markdown]
# Totals on the different distractions while driving

# %%
distract1['distractionData'].value_counts().to_frame()
# Out:
#                                                     distractionData
# Not Distracted                                                33274
# Unknown if Distracted                                          7029
# Not Reported                                                   4688
# Inattention (Inattentive), Details Unknown                     1209
# Distraction/Inattention                                         420
# Looked But Did Not See                                          397
# Other Distraction                                               324
# No Driver Present/Unknown if Driver Present                     268
# Distraction (Distracted), Details Unknown                       248
# Other Cellular Phone Related                                    203
# Distracted by Outside Person, Object or Event                   192
# By Other Occupant(s)                                            159
# While Manipulating Cellular Phone                               146
# While Talking or Listening to Cellular Phone                    115
# While Using or Reaching For Device/Object Broug...               72
# Careless/Inattentive                                             49
# Eating or Drinking                                               47
# While Adjusting Audio or Climate Controls                        43
# While Using Other Component/Controls Integral t...               35
# Lost In Thought/Day Dreaming                                     15
# Smoking Related                                                  12
# By a Moving Object in Vehicle                                    10
# Distraction/Careless                                              7

# %% [markdown]
# Total distractions by state

# %%
distract1.groupby(['state']).agg({'MDRDSTRD':sum})
# Out:
#                       MDRDSTRD
# state
# Alabama                  41070
# Alaska                    5285
# Arizona                  58076
# Arkansas                 48074
# California              100044
# Colorado                 27115
# Connecticut              17203
# Delaware                  3434
# District of Columbia      2367
# Florida                 123892
# Georgia                  28270
# Hawaii                    3698
# Idaho                     5881
# Illinois                 54505
# Indiana                   1118
# Iowa                     18253
# Kansas                   17916
# Kentucky                 18403
# Louisiana                48966
# Maine                     7729
# Maryland                 29030
# Massachusetts            23217
# Michigan                 41118
# Minnesota                13226
# Mississippi              78973
# Missouri                  2505
# Montana                   8567
# Nebraska                   841
# Nevada                    5044
# New Hampshire             2283
# New Jersey               18685
# New Mexico               16320
# New York                  3316
# North Carolina           20527
# North Dakota               330
# Ohio                     10084
# Oklahoma                 35768
# Oregon                   48561
# Pennsylvania              7966
# Rhode Island              2784
# South Carolina          114886
# South Dakota              2771
# Tennessee                48922
# Texas                    39048
# Utah                     16724
# Vermont                    240
# Virginia                 21451
# Washington               43925
# West Virginia              827
# Wisconsin                37067
# Wyoming                  10388

# %% [markdown]
# Total number of MDRDSTRD (distractions)

# %%
distract1["MDRDSTRD"].sum()
# Out:
# 1336693

# %% [markdown]
# Total number of fatals by state

# %%
distract1.groupby(['state']).agg({'FATALS':sum})
# Out:
#                       FATALS
# state
# Alabama                 1316
# Alaska                   101
# Arizona                 1394
# Arkansas                 844
# California              4881
# Colorado                 868
# Connecticut              402
# Delaware                 199
# District of Columbia      30
# Florida                 4631
# Georgia                 2267
# Hawaii                   146
# Idaho                    308
# Illinois                1508
# Indiana                 1302
# Iowa                     490
# Kansas                   522
# Kentucky                1208
# Louisiana               1090
# Maine                    217
# Maryland                 807
# Massachusetts            437
# Michigan                1558
# Minnesota                662
# Mississippi              992
# Missouri                1362
# Montana                  303
# Nebraska                 385
# Nevada                   507
# New Hampshire            165
# New Jersey               827
# New Mexico               434
# New York                1639
# North Carolina          2136
# North Dakota             203
# Ohio                    1773
# Oklahoma                 988
# Oregon                   653
# Pennsylvania            1861
# Rhode Island              65
# South Carolina          1570
# South Dakota             207
# Tennessee               1543
# Texas                   5641
# Utah                     463
# Vermont                   82
# Virginia                1095
# Washington               895
# West Virginia            396
# Wisconsin                882
# Wyoming                  239

# %% [markdown]
# Total number of fatals

# %%
distract1["FATALS"].sum()
# Out:
# 54494

# %% [markdown]
# Total number of driving while intoxicated by state

# %%
distract1.groupby(['state']).agg({'DRUNK_DR':sum})
# Out:
#                       DRUNK_DR
# state
# Alabama                    309
# Alaska                      30
# Arizona                    374
# Arkansas                   196
# California                1139
# Colorado                   256
# Connecticut                128
# Delaware                    52
# District of Columbia         6
# Florida                    967
# Georgia                    453
# Hawaii                      39
# Idaho                       90
# Illinois                   415
# Indiana                    202
# Iowa                       104
# Kansas                      90
# Kentucky                   267
# Louisiana                  353
# Maine                      102
# Maryland                   222
# Massachusetts              103
# Michigan                   392
# Minnesota                  189
# Mississippi                178
# Missouri                   297
# Montana                    108
# Nebraska                    98
# Nevada                     162
# New Hampshire               41
# New Jersey                 126
# New Mexico                 126
# New York                   318
# North Carolina             556
# North Dakota                68
# Ohio                       447
# Oklahoma                   235
# Oregon                     205
# Pennsylvania               447
# Rhode Island                26
# South Carolina             419
# South Dakota                52
# Tennessee                  369
# Texas                     1253
# Utah                        68
# Vermont                     18
# Virginia                   322
# Washington                 238
# West Virginia               90
# Wisconsin                  256
# Wyoming                     64

# %% [markdown]
# Total number of drunk drivers

# %%
distract1["DRUNK_DR"].sum()
# Out:
# 13065

# %% [markdown]
# Total number of people in vehicles at time of accidents

# %%
distract1.groupby(['state']).agg({'PERSONS':sum})
# Out:
#                       PERSONS
# state
# Alabama                  3429
# Alaska                    326
# Arizona                  3728
# Arkansas                 2011
# California              12880
# Colorado                 2357
# Connecticut              1119
# Delaware                  534
# District of Columbia       69
# Florida                 11994
# Georgia                  5894
# Hawaii                    353
# Idaho                     742
# Illinois                 3616
# Indiana                  3526
# Iowa                     1123
# Kansas                   1225
# Kentucky                 3019
# Louisiana                2657
# Maine                     461
# Maryland                 1972
# Massachusetts             969
# Michigan                 8067
# Minnesota                1751
# Mississippi              2276
# Missouri                 3610
# Montana                   671
# Nebraska                  862
# Nevada                   1450
# New Hampshire             325
# New Jersey               2403
# New Mexico               1149
# New York                 4072
# North Carolina           5352
# North Dakota              562
# Ohio                     7183
# Oklahoma                 2595
# Oregon                   1763
# Pennsylvania             5134
# Rhode Island              174
# South Carolina           3954
# South Dakota              485
# Tennessee                3854
# Texas                   14714
# Utah                     1692
# Vermont                   167
# Virginia                 2363
# Washington               2831
# West Virginia             915
# Wisconsin                2195
# Wyoming                   950

# %% [markdown]
# Total number of persons

# %%
distract1["PERSONS"].sum()
# Out:
# 147523

# %%
distract1.dropna(inplace=True)

# %%
distract1.head()
# Out:
#    STATE  PEDS  PERSONS   LATITUDE   LONGITUD  SCH_BUS  CF1  CF2  CF3  FATALS  \
# 0      1     0        1  33.878653 -87.325328        0    0    0    0       1
# 1      1     0        1  34.910442 -86.908708        0    0    0    0       1
# 2      1     0        2  32.142006 -85.758456        0    0    0    0       1
# 3      1     0        1  31.439814 -85.510300        0    0    0    0       1
# 4      1     0        2  31.319331 -85.515100        0    0    0    0       1
#
#    DRUNK_DR  VEH_NO  MDRDSTRD        distractionData    state
# 0         1       1        99  Unknown if Distracted  Alabama
# 1         0       1         0         Not Distracted  Alabama
# 2         1       1         0         Not Distracted  Alabama
# 3         1       1        99  Unknown if Distracted  Alabama
# 4         0       1        99  Unknown if Distracted  Alabama

# %%
p = pd.pivot_table(distract1, values='MDRDSTRD', 
                   index=['state'], columns=['distractionData'], aggfunc=np.sum)

# %%
p.head()
# Out:
# distractionData  By Other Occupant(s)  By a Moving Object in Vehicle  \
# state
# Alabama                          24.0                            NaN
# Alaska                            6.0                            4.0
# Arizona                          24.0                            NaN
# Arkansas                          NaN                            NaN
# California                       45.0                            NaN
#
# distractionData  Careless/Inattentive  \
# state
# Alabama                           NaN
# Alaska                            NaN
# Arizona                           NaN
# Arkansas                        323.0
# California                       38.0
#
# distractionData  Distracted by Outside Person, Object or Event  \
# state
# Alabama                                                   96.0
# Alaska                                                    48.0
# Arizona                                                  120.0
# Arkansas                                                 120.0
# California                                                96.0
#
# distractionData  Distraction (Distracted), Details Unknown  \
# state
# Alabama                                             1012.0
# Alaska                                                 NaN
# Arizona                                               92.0
# Arkansas                                              92.0
# California                                           184.0
#
# distractionData  Distraction/Careless  Distraction/Inattention  \
# state
# Alabama                           NaN                     17.0
# Alaska                            NaN                      NaN
# Arizona                           NaN                    153.0
# Arkansas                          NaN                      NaN
# California                        NaN                    153.0
#
# distractionData  Eating or Drinking  \
# state
# Alabama                         NaN
# Alaska                         26.0
# Arizona                        13.0
# Arkansas                        NaN
# California                     78.0
#
# distractionData  Inattention (Inattentive), Details Unknown  \
# state
# Alabama                                                 NaN
# Alaska                                                  NaN
# Arizona                                                 NaN
# Arkansas                                                NaN
# California                                           1767.0
#
# distractionData  Looked But Did Not See  Lost In Thought/Day Dreaming  \
# state
# Alabama                             8.0                           NaN
# Alaska                              NaN                           NaN
# Arizona                            64.0                           NaN
# Arkansas                            1.0                           NaN
# California                         51.0                           NaN
#
# distractionData  No Driver Present/Unknown if Driver Present  Not Distracted  \
# state
# Alabama                                                 48.0             0.0
# Alaska                                                   NaN             0.0
# Arizona                                                 48.0             0.0
# Arkansas                                                16.0             0.0
# California                                             544.0             0.0
#
# distractionData  Not Reported  Other Cellular Phone Related  \
# state
# Alabama                   NaN                          75.0
# Alaska                 2112.0                           NaN
# Arizona                 960.0                          90.0
# Arkansas              26496.0                          15.0
# California            53088.0                          30.0
#
# distractionData  Other Distraction  Smoking Related  Unknown if Distracted  \
# state
# Alabama                      196.0             14.0                39501.0
# Alaska                        98.0              NaN                 2970.0
# Arizona                      294.0              NaN                56133.0
# Arkansas                     490.0              NaN                20493.0
# California                  1372.0             14.0                42372.0
#
# distractionData  While Adjusting Audio or Climate Controls  \
# state
# Alabama                                                7.0
# Alaska                                                 NaN
# Arizona                                               14.0
# Arkansas                                               NaN
# California                                            35.0
#
# distractionData  While Manipulating Cellular Phone  \
# state
# Alabama                                       42.0
# Alaska                                        12.0
# Arizona                                       18.0
# Arkansas                                      18.0
# California                                    54.0
#
# distractionData  While Talking or Listening to Cellular Phone  \
# state
# Alabama                                                  10.0
# Alaska                                                    NaN
# Arizona                                                  25.0
# Arkansas                                                 10.0
# California                                               85.0
#
# distractionData  While Using Other Component/Controls Integral to Vehicle  \
# state
# Alabama                                                        NaN
# Alaska                                                         9.0
# Arizona                                                       18.0
# Arkansas                                                       NaN
# California                                                    18.0
#
# distractionData  While Using or Reaching For Device/Object Brought Into Vehicle
# state
# Alabama                                                       20.0
# Alaska                                                         NaN
# Arizona                                                       10.0
# Arkansas                                                       NaN
# California                                                    20.0

# %%
x = distract1[['STATE', 'PEDS', 'PERSONS', 'LATITUDE', 'LONGITUD', ]]

# %%
y = distract1['MDRDSTRD']

# %%
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.4,random_state=101)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (29377, 5) (29377,)
# (19585, 5) (19585,)

# %%
sns.scatterplot(x='LONGITUD', y='LATITUDE', data=distract1, hue='STATE', legend=False,s=20)
plt.show()

# %%
sns.scatterplot(x='LONGITUD', y='LATITUDE', data=distract1, hue='MDRDSTRD', legend=False,s=20)
plt.show()

# %%
sns.scatterplot(x='LONGITUD', y='LATITUDE', data=distract1, hue='FATALS', legend=False,s=20)
plt.show()

# %%
sns.scatterplot(x='MDRDSTRD', y='FATALS', data=distract1, hue='STATE', legend=False,s=20)
plt.show()

# %%
sns.scatterplot(x='MDRDSTRD', y='DRUNK_DR', data=distract1, hue='STATE', legend=False,s=20)
plt.show()

# %% [markdown]
# # Assumptions for Linear Regression

# %% [markdown]
# Testing Assumptions

# %% [markdown]
# Testing for Linear Relationship between x and y -this is a funnel shape and not a straight line

# %%
sns.pairplot(distract1)

# %%
sns.distplot(distract1['MDRDSTRD'])
# Out:
# C:\Python3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MDRDSTRD', ylabel='Density'>

# %%
sns.distplot(distract1['DRUNK_DR'])
# Out:
# C:\Python3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DRUNK_DR', ylabel='Density'>

# %%
X = distract1['MDRDSTRD']
y = distract1['DRUNK_DR']

# %%
model = sm.OLS(y,x).fit()

# %% [markdown]
# Testing for Homoscedasticity -is not normal

# %%
pred_val = model.fittedvalues.copy()
true_val = distract1['MDRDSTRD'].values.copy()
residual = true_val - pred_val

# %%
fig, ax = plt.subplots(figsize=(6, 2.5))
_ = ax.scatter(residual, pred_val)

# %% [markdown]
# Breuch Pagan Test

# %%
sms.diagnostic.het_breuschpagan(residual, distract1[['MDRDSTRD']])
# Out:
# (48853.79648443349, nan, 22105850.416700795, 0.0)

# %% [markdown]
# Is < .05 (stastically significant), which means assumption of homoscedasticity and your data is, in fact, heteroscedasticy
# generalized least squares would possible work better

# %% [markdown]
# Testing for Homegenity of Variance - is not constant

# %% [markdown]
# Testing the X as a known Constant - unknown error

# %% [markdown]
# Multicollinearity: the observations are independent

# %%
distract1.corr()
# Out:
#              STATE      PEDS   PERSONS  LATITUDE  LONGITUD   SCH_BUS  \
# STATE     1.000000 -0.039259  0.015912  0.140014  0.005028  0.004655
# PEDS     -0.039259  1.000000 -0.089630 -0.015732  0.010646 -0.011088
# PERSONS   0.015912 -0.089630  1.000000  0.018296 -0.014422  0.052766
# LATITUDE  0.140014 -0.015732  0.018296  1.000000  0.649353  0.001903
# LONGITUD  0.005028  0.010646 -0.014422  0.649353  1.000000 -0.003253
# SCH_BUS   0.004655 -0.011088  0.052766  0.001903 -0.003253  1.000000
# CF1      -0.026402  0.071068  0.105246  0.005647 -0.018051 -0.008382
# CF2      -0.001139  0.045892  0.021327  0.005152 -0.003102 -0.004633
# CF3      -0.009148  0.006497  0.000094  0.013373  0.001711 -0.002342
# FATALS    0.013322 -0.020301  0.172080 -0.010569 -0.003564 -0.003356
# DRUNK_DR  0.013018 -0.145001 -0.056139  0.022856 -0.003259 -0.023650
# VEH_NO    0.009535 -0.048471  0.713111  0.017966 -0.007345  0.008794
# MDRDSTRD -0.052335 -0.031322 -0.040429  0.017873  0.009410 -0.006864
#
#                CF1       CF2       CF3    FATALS  DRUNK_DR    VEH_NO  MDRDSTRD
# STATE    -0.026402 -0.001139 -0.009148  0.013322  0.013018  0.009535 -0.052335
# PEDS      0.071068  0.045892  0.006497 -0.020301 -0.145001 -0.048471 -0.031322
# PERSONS   0.105246  0.021327  0.000094  0.172080 -0.056139  0.713111 -0.040429
# LATITUDE  0.005647  0.005152  0.013373 -0.010569  0.022856  0.017966  0.017873
# LONGITUD -0.018051 -0.003102  0.001711 -0.003564 -0.003259 -0.007345  0.009410
# SCH_BUS  -0.008382 -0.004633 -0.002342 -0.003356 -0.023650  0.008794 -0.006864
# CF1       1.000000  0.561000  0.511265  0.019081 -0.021188  0.088534 -0.027694
# CF2       0.561000  1.000000  0.876784  0.018254 -0.015355  0.019091  0.010365
# CF3       0.511265  0.876784  1.000000  0.000611 -0.005947  0.001751  0.024386
# FATALS    0.019081  0.018254  0.000611  1.000000  0.043739  0.040706  0.006455
# DRUNK_DR -0.021188 -0.015355 -0.005947  0.043739  1.000000 -0.048525  0.070326
# VEH_NO    0.088534  0.019091  0.001751  0.040706 -0.048525  1.000000 -0.063431
# MDRDSTRD -0.027694  0.010365  0.024386  0.006455  0.070326 -0.063431  1.000000

# %%
sns.heatmap(distract1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Testing for Outliers - Three outliers

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(model, alpha = .05, ax = ax, criterion="cooks")

# %%
infl = model.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_STATE  dfb_PEDS  dfb_PERSONS  dfb_LATITUDE  dfb_LONGITUD   cooks_d  \
# 0      -0.010880 -0.002926    -0.003405      0.011691     -0.004215  0.000036
# 1       0.004451  0.001197     0.001409     -0.004826      0.001637  0.000006
# 2      -0.010676 -0.002705    -0.001339      0.010716     -0.004114  0.000033
# 3      -0.010401 -0.002794    -0.003147      0.011002     -0.004351  0.000033
# 4       0.003537  0.000894     0.000416     -0.003520      0.001409  0.000004
# ...          ...       ...          ...           ...           ...       ...
# 48957  -0.005168  0.001268     0.001363      0.001706     -0.000043  0.000009
# 48958  -0.005168  0.001268     0.001363      0.001706     -0.000043  0.000009
# 48959  -0.004895  0.001088    -0.000360      0.002112     -0.000263  0.000008
# 48960  -0.004895  0.001088    -0.000360      0.002112     -0.000263  0.000008
# 48961  -0.005146  0.001642     0.002746      0.000812      0.000042  0.000011
#
#        standard_resid  hat_diag  dffits_internal  student_resid    dffits
# 0            1.562057  0.000073         0.013373       1.562080  0.013374
# 1           -0.622179  0.000077        -0.005469      -0.622175 -0.005469
# 2            1.609013  0.000063         0.012761       1.609039  0.012761
# 3            1.602516  0.000064         0.012789       1.602542  0.012789
# 4           -0.545982  0.000060        -0.004230      -0.545978 -0.004230
# ...               ...       ...              ...            ...       ...
# 48957       -0.737787  0.000081        -0.006649      -0.737784 -0.006649
# 48958       -0.737787  0.000081        -0.006649      -0.737784 -0.006649
# 48959       -0.707564  0.000078        -0.006230      -0.707560 -0.006230
# 48960       -0.707564  0.000078        -0.006230      -0.707560 -0.006230
# 48961       -0.816372  0.000084        -0.007495      -0.816369 -0.007495
#
# [48962 rows x 11 columns]

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               DRUNK_DR   R-squared (uncentered):                   0.264
# Model:                            OLS   Adj. R-squared (uncentered):              0.264
# Method:                 Least Squares   F-statistic:                              3518.
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):                        0.00
# Time:                        14:25:46   Log-Likelihood:                         -31580.
# No. Observations:               48962   AIC:                                  6.317e+04
# Df Residuals:                   48957   BIC:                                  6.321e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# STATE          0.0001      0.000      1.079      0.280      -0.000       0.000
# PEDS          -0.1525      0.005    -32.605      0.000      -0.162      -0.143
# PERSONS       -0.0082      0.001    -14.995      0.000      -0.009      -0.007
# LATITUDE       0.0073      0.000     60.901      0.000       0.007       0.008
# LONGITUD      -0.0005   2.32e-05    -19.738      0.000      -0.001      -0.000
# ==============================================================================
# Omnibus:                     9339.619   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15621.986
# Skew:                           1.330   Prob(JB):                         0.00
# Kurtosis:                       3.760   Cond. No.                         277.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.plot(distract1['STATE'], distract1['MDRDSTRD'])
plt.xlabel('STATE')
plt.ylabel('DISTRACTIONS')
plt.title("Distractions in each state while involved in accidents")
# Out:
# Text(0.5, 1.0, 'Distractions in each state while involved in accidents')

# %%
distract1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_6da82_row0_col0, #T_6da82_row1_col1, #T_6da82_row2_col2, #T_6da82_row3_col3, #T_6da82_row4_col4, #T_6da82_row5_col5, #T_6da82_row6_col6, #T_6da82_row7_col7, #T_6da82_row8_col8, #T_6da82_row9_col9, #T_6da82_row10_col10, #T_6da82_row11_col11, #T_6da82_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col1, #T_6da82_row4_col5, #T_6da82_row4_col7, #T_6da82_row4_col9, #T_6da82_row4_col10, #T_6da82_row5_col1, #T_6da82_row5_col6, #T_6da82_row7_col0, #T_6da82_row7_col4, #T_6da82_row8_col1, #T_6da82_row11_col1, #T_6da82_row11_col10 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col2, #T_6da82_row9_col10, #T_6da82_row12_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col4, #T_6da82_row0_col5, #T_6da82_row11_col4, #T_6da82_row12_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col6, #T_6da82_row4_col12, #T_6da82_row5_col3, #T_6da82_row7_col12, #T_6da82_row9_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col7, #T_6da82_row1_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col9, #T_6da82_row0_col10, #T_6da82_row0_col11, #T_6da82_row7_col1, #T_6da82_row9_col11, #T_6da82_row11_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6da82_row0_col12, #T_6da82_row1_col10, #T_6da82_row2_col1, #T_6da82_row3_col1, #T_6da82_row4_col2, #T_6da82_row4_col6, #T_6da82_row5_col10, #T_6da82_row6_col0, #T_6da82_row6_col12, #T_6da82_row7_col10, #T_6da82_row8_col0, #T_6da82_row8_col10, #T_6da82_row9_col1, #T_6da82_row10_col1, #T_6da82_row11_col12, #T_6da82_row12_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col3, #T_6da82_row6_col11, #T_6da82_row10_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col6, #T_6da82_row9_col2, #T_6da82_row10_col12 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col7, #T_6da82_row10_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col8, #T_6da82_row2_col5, #T_6da82_row6_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col9, #T_6da82_row10_col5, #T_6da82_row10_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col11, #T_6da82_row2_col8, #T_6da82_row10_col11, #T_6da82_row12_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6da82_row1_col12, #T_6da82_row2_col3, #T_6da82_row11_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col0, #T_6da82_row6_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col4, #T_6da82_row11_col0, #T_6da82_row11_col5, #T_6da82_row12_col4, #T_6da82_row12_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6da82_row2_col10, #T_6da82_row3_col8, #T_6da82_row4_col1, #T_6da82_row5_col0, #T_6da82_row12_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6da82_row2_col11 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_6da82_row2_col12, #T_6da82_row6_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col2, #T_6da82_row3_col11, #T_6da82_row3_col12, #T_6da82_row5_col11, #T_6da82_row6_col3, #T_6da82_row7_col9, #T_6da82_row7_col11, #T_6da82_row8_col12, #T_6da82_row9_col0, #T_6da82_row12_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col4, #T_6da82_row4_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_6da82_row3_col5, #T_6da82_row4_col8, #T_6da82_row5_col7, #T_6da82_row5_col12, #T_6da82_row6_col5, #T_6da82_row9_col4, #T_6da82_row9_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col6, #T_6da82_row3_col7, #T_6da82_row4_col0, #T_6da82_row5_col4, #T_6da82_row5_col8, #T_6da82_row5_col9, #T_6da82_row7_col3, #T_6da82_row8_col3, #T_6da82_row9_col8, #T_6da82_row12_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col9, #T_6da82_row6_col10, #T_6da82_row8_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6da82_row3_col10, #T_6da82_row7_col2, #T_6da82_row9_col6, #T_6da82_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6da82_row4_col11, #T_6da82_row6_col4, #T_6da82_row7_col5, #T_6da82_row8_col2, #T_6da82_row8_col4, #T_6da82_row8_col9, #T_6da82_row8_col11, #T_6da82_row9_col3, #T_6da82_row12_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6da82_row5_col2, #T_6da82_row10_col2, #T_6da82_row11_col3, #T_6da82_row11_col7, #T_6da82_row12_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6da82_row6_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_6da82_row6_col8 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_6da82_row7_col6 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_6da82_row7_col8, #T_6da82_row8_col7 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_6da82_row8_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6da82_row10_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6da82_row10_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6da82_row10_col4, #T_6da82_row10_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_6da82_row11_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_6da82_row11_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6da82_row12_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6da82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6da82_level0_col0" class="col_heading level0 col0" >STATE</th>
#       <th id="T_6da82_level0_col1" class="col_heading level0 col1" >PEDS</th>
#       <th id="T_6da82_level0_col2" class="col_heading level0 col2" >PERSONS</th>
#       <th id="T_6da82_level0_col3" class="col_heading level0 col3" >LATITUDE</th>
#       <th id="T_6da82_level0_col4" class="col_heading level0 col4" >LONGITUD</th>
#       <th id="T_6da82_level0_col5" class="col_heading level0 col5" >SCH_BUS</th>
#       <th id="T_6da82_level0_col6" class="col_heading level0 col6" >CF1</th>
#       <th id="T_6da82_level0_col7" class="col_heading level0 col7" >CF2</th>
#       <th id="T_6da82_level0_col8" class="col_heading level0 col8" >CF3</th>
#       <th id="T_6da82_level0_col9" class="col_heading level0 col9" >FATALS</th>
#       <th id="T_6da82_level0_col10" class="col_heading level0 col10" >DRUNK_DR</th>
#       <th id="T_6da82_level0_col11" class="col_heading level0 col11" >VEH_NO</th>
#       <th id="T_6da82_level0_col12" class="col_heading level0 col12" >MDRDSTRD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6da82_level0_row0" class="row_heading level0 row0" >STATE</th>
#       <td id="T_6da82_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_6da82_row0_col1" class="data row0 col1" >-0.039</td>
#       <td id="T_6da82_row0_col2" class="data row0 col2" >0.016</td>
#       <td id="T_6da82_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_6da82_row0_col4" class="data row0 col4" >0.005</td>
#       <td id="T_6da82_row0_col5" class="data row0 col5" >0.0047</td>
#       <td id="T_6da82_row0_col6" class="data row0 col6" >-0.026</td>
#       <td id="T_6da82_row0_col7" class="data row0 col7" >-0.0011</td>
#       <td id="T_6da82_row0_col8" class="data row0 col8" >-0.0091</td>
#       <td id="T_6da82_row0_col9" class="data row0 col9" >0.013</td>
#       <td id="T_6da82_row0_col10" class="data row0 col10" >0.013</td>
#       <td id="T_6da82_row0_col11" class="data row0 col11" >0.0095</td>
#       <td id="T_6da82_row0_col12" cla

# %% [markdown]
# Pie Chart

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["MDRDSTRD", "DRUNK_DR", "Cell_Phone", "PERSON"]

plt.pie(y, labels = mylabels)
plt.legend(title = "DISTRACTIVE_DRIVING")
plt.show()
